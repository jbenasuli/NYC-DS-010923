# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#5642C5;
#            font-size:200%;
#            font-family:Arial;letter-spacing:0.5px">
#
# <p width = 20%, style="padding: 10px;
#               color:white;">
# Neural Networks: Regularization
# </p>
# </div>
#
# Data Science Cohort Live NYC March 2023
# <p>Phase 4: Topic 39</p>
# <br>
# <br>
#
# <div align = "right">
# <img src="Images/flatiron-school-logo.png" align = "right" width="200"/>
# </div>

# %%
from sklearn.datasets import load_sample_images
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import accuracy_score, confusion_matrix
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import pandas as pd
from sklearn.metrics import ConfusionMatrixDisplay
import seaborn as sns

from tensorflow.keras import datasets
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Flatten # takes 2D input and turns into 1D array
from tensorflow.keras import regularizers

import os
import sys
module_path = os.path.abspath(os.path.join(os.pardir, os.pardir))
if module_path not in sys.path:
    sys.path.append(module_path)
    
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Things to remember:

# %% [markdown]
# ## STEPS ##
#
# 1. Load Data
# 2. Define Keras Model
# 3. Compile Keras Model
# 4. Fit Keras Model
# 5. Evaluate Keras Model
# 6. Make Predictions

# %% [markdown]
# - The data and labels in `fit()` need to be numpy arrays, not `pandas` dfs.
# - Scaling your data will have a large impact on your model.
#    > For our traditional input features, we would use a scaler object. For images, as long as the minimum value is 0, we can simply divide through by the maximum pixel intensity.

# %% [markdown]
# #### Regularization
# - Retain complexity of neural network: many weights to learn interesting relationships
# - Make our weights less susceptible to overfitting
#
# **Getting neural networks to perform really well**

# %% [markdown]
# In neural networks, two main forms of regularization:
# - L2 Regularization (something familiar)
# - Dropout Regularization (something a little new)

# %% [markdown]
# **L2 Regularization**
#
# - Add penalty on weight **matrices**.
# $$ J \rightarrow J' $$
# $$ J = \sum_{i=1}^m \frac{1}{m}L(y_i, \hat{y}_i) $$
# $$ J' = \sum_{i=1}^m \frac{1}{m}L(y_i, \hat{y}_i) + \frac{\lambda}{2} \sum_{l=1}^L \lVert  W^{[l]}   \rVert_F^2 $$

# %% [markdown]
# where $F$ denotes the Frobenius norm.

# %% [markdown]
# Frobenius norm is square root of sum of of element-wise square:
# i.e.
# $$ \lVert  A   \rVert_F = \sqrt{\sum_{i,j} A_{ij}^2 }$$

# %%
import numpy as np
from numpy.linalg import norm

# %%
A = np.array([[1,2],[0,3]])
A
# Out:
# array([[1, 2],
#        [0, 3]])

# %%
norm(A, 'fro')
# Out:
# 3.7416573867739413

# %%
np.sqrt(1**2 + 0**2 + 2**2 + 3**2)
# Out:
# 3.7416573867739413

# %% [markdown]
# Modiied objective functon:
#
# $$ J' = \sum_{i=1}^m \frac{1}{m}L(y_i, \hat{y}_i) + \frac{\lambda}{2} \sum_{l=1}^L \lVert  W^{[l]}   \rVert_F^2 $$

# %% [markdown]
# Regularization serves to penalize any particular weight from being too large:
# - smoothens/redistributes weights for each weight matrix
# - aids in generalization

# %% [markdown]
# L2 regularization: often known as weight decay
# - Perspective: gradient descent
# $$ J' = \sum_{i=1}^m \frac{1}{m}L(y_i, \hat{y}_i) + \frac{\lambda}{2} \sum_{l=1}^L \lVert  W^{[l]}   \rVert_F^2 $$
# $$ W^{[l]} \rightarrow W^{[l]} - \alpha \frac{\partial J'}{\partial W^{[l]}} $$

# %% [markdown]
# $$ J = \sum_{i=1}^m \frac{1}{m}L(y_i, \hat{y}_i) $$
# $$ W^{[l]} \rightarrow \Big(W^{[l]}  - \alpha \frac{\lambda}{2 m}  W^{[l]} \Big) - \alpha \frac{\partial J}{\partial W^{[l]}}$$
#
# - At each iteration regularization tries to reduce magnitude of weight matrix.

# %% [markdown]
# #### Implementing L2 regularization in Keras

# %%
# creates keras regularizer object
from tensorflow.keras.regularizers import l2

# %% [markdown]
# L2 regularizer object takes in $\lambda$ parameter as argument

# %%
reg = l2(3e-3) # 1e-5 to .1

# %% [markdown]
# Implementing regularization to weights in Keras:
# - Dense(kernel_regularizer = __)
# - takes in string ('l2') or regularizer object

# %% [markdown]
# Less common but also used:
#
# - can apply regularization to bias terms
# - Dense(bias_regularizer = __)

# %%
# load in the data
(x_train, y_train), (x_test, y_test) = datasets.mnist.load_data()

x_train = x_train/255 # normalization
x_test = x_test/255

# Keras requires multi-class labels to be one-hot encoded
y_tr_one_hot = to_categorical(y_train)
y_tt_one_hot = to_categorical(y_test)

# %%
model_images = Sequential()
model_images.add(Flatten(input_shape=(28, 28))) # flattens each 28x28 image into a vector
model_images.add(Dense(32, activation='relu', kernel_regularizer = reg)) # take in regularizer
model_images.add(Dense(8, activation='relu', kernel_regularizer = reg))
model_images.add(Dense(10, activation='softmax')) # number of units = number of target classes
# Out:
# Metal device set to: Apple M1
# 2023-03-21 12:48:43.745270: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-03-21 12:48:43.745400: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
model_images.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['accuracy'] )

# %%
# verbose=1 allows you to see the output.
# To see only the metrics at the end of each epoch, set verbose=2.
history_mnist = model_images.fit(x_train, y_tr_one_hot, epochs=50, batch_size= 32, validation_split = 0.2)
# Out:
# Epoch 1/50
# 2023-03-21 12:48:44.055687: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2023-03-21 12:48:44.189717: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1500/1500 [==============================] - ETA: 0s - loss: 0.7181 - accuracy: 0.8358
# 2023-03-21 12:48:55.004217: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.7181 - accuracy: 0.8358 - val_loss: 0.4617 - val_accuracy: 0.9122
# Epoch 2/50
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.4394 - accuracy: 0.9176 - val_loss: 0.3998 - val_accuracy: 0.9285
# Epoch 3/50
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.3911 - accuracy: 0.9313 - val_loss: 0.3536 - val_accuracy: 0.9450
# Epoch 4/50
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.3615 - accuracy: 0.9385 - val_loss: 0.3396 - val_accuracy: 0.9453
# Epoch 5/50
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.3417 - accuracy: 0.9431 - val_loss: 0.3245 - val_accuracy: 0.9463
# Epoch 6/50
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.3264 - accuracy: 0.9459 - val_loss: 0.3058 - val_accuracy: 0.9526
# Epoch 7/50
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.3142 - accuracy: 0.9482 - val_loss: 0.3021 - val_accuracy: 0.9536
# Epoch 8/50
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.3032 - accuracy: 0.9517 - val_loss: 0.2903 - val_accuracy: 0.9554
# Epoch 9/50
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.2937 - accuracy: 0.9534 - val_loss: 0.2806 - val_accuracy: 0.9562
# Epoch 10/50
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.2854 - accuracy: 0.9539 - val_loss: 0.3022 - val_accuracy: 0.9497
# Epoch 11/50
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.2803 - accuracy: 0.9545 - val_loss: 0.2952 - val_accuracy: 0.9517
# Epoch 12/50
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.2745 - accuracy: 0.9561 - val_loss: 0.2735 - val_accuracy: 0.9559
# Epoch 13/50
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.2682 - accuracy: 0.9562 - val_loss: 0.2922 - val_accuracy: 0.9497
# Epoch 14/50
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.2639 - accuracy: 0.9573 - val_loss: 0.2634 - val_accuracy: 0.9577
# Epoch 15/50
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.2592 - accuracy: 0.9579 - val_loss: 0.2595 - val_accuracy: 0.9570
# Epoch 16/50
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.2559 - accuracy: 0.9584 - val_loss: 0.2640 - val_accuracy: 0.9552
# Epoch 17/50
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.2516 - accuracy: 0.9596 - val_loss: 0.2523 - val_accuracy: 0.9597
# Epoch 18/50
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.2493 - accuracy: 0.9590 - val_loss: 0.2518 - val_accuracy: 0.9606
# Epoch 19/50
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.2466 - accuracy: 0.9599 - val_loss: 0.2473 - val_accuracy: 0.9621
# Epoch 20/50
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.2441 - accuracy: 0.9603 - val_loss: 0.2556 - val_accuracy: 0.9561
# Epoch 21/50
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.2419 - accuracy: 0.9607 - val_loss: 0.2337 - val_accuracy: 0.9647
# Epoch 22/50
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.2374 - accuracy: 0.9618 - val_loss: 0.2358 - val_accuracy: 0.9636
# Epoch 23/50
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.2362 - accuracy: 0.9615 - val_loss: 0.2338 - val_accuracy: 0.9620
# Epoch 24/50
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.2338 - accuracy: 0.9615 - val_loss: 0.2326 - val_accuracy: 0.9632
# Epoch 25/50
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.2304 - accuracy: 0.9621 - val_loss: 0.2578 - val_accuracy: 0.9543
# Epoch 26/50
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.2310 - accuracy: 0.9614 - val_loss: 0.2372 - val_accuracy: 0.9604
# Epoch 27/50
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.2275 - accuracy: 0.9620 - val_loss: 0.2345 - val_accuracy: 0.9627
# Epoch 28/50
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.2260 - accuracy: 0.9625 - val_loss: 0.2361 - val_accuracy: 0.9608
# Epoch 29/50
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.2247 - accuracy: 0.9624 - val_loss: 0.2333 - val_accuracy: 0.9595
# Epoch 30/50
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.2243 - accuracy: 0.9627 - val_loss: 0.2247 - val_accuracy: 0.9625
# Epoch 31/50
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.2212 - accuracy: 0.9639 - val_loss: 0.2189 - val_accuracy: 0.9655
# Epoch 32/50
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.2213 - accuracy: 0.9626 - val_loss: 0.2354 - val_accuracy: 0.9591
# Epoch 33/50
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.2190 - accuracy: 0.9640 - val_loss: 0.2272 - val_accuracy: 0.9607
# Epoch 34/50
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.2202 - accuracy: 0.9629 - val_loss: 0.2266 - val_accuracy: 0.9600
# Epoch 35/50
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.2165 - accuracy: 0.9638 - val_loss: 0.2335 - val_accuracy: 0.9602
# Epoch 36/50
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.2149 - accuracy: 0.9642 - val_loss: 0.2242 - val_accuracy: 0.9596
# Epoch 37/50
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.2174 - accuracy: 0.9632 - val_loss: 0.2261 - val_accuracy: 0.9607
# Epoch 38/50
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.2131 - accuracy: 0.9642 - val_loss: 0.2123 - val_accuracy: 0.9657
# Epoch 39/50
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.2118 - accuracy: 0.9644 - val_loss: 0.2365 - val_accuracy: 0.9592
# Epoch 40/50
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.2114 - accuracy: 0.9649 - val_loss: 0.2153 - val_accuracy: 0.9634
# Epoch 41/50
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.2103 - accuracy: 0.9651 - val_loss: 0.2183 - val_accuracy: 0.9628
# Epoch 42/50
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.2110 - accuracy: 0.9642 - val_loss: 0.2329 - val_accuracy: 0.9602
# Epoch 43/50
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.2103 - accuracy: 0.9637 - val_loss: 0.2099 - val_accuracy: 0.9652
# Epoch 44/50
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.2101 - accuracy: 0.9637 - val_loss: 0.2130 - val_accuracy: 0.9648
# Epoch 45/50
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.2089 - accuracy: 0.9648 - val_loss: 0.2140 - val_accuracy: 0.9648
# Epoch 46/50
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.2082 - accuracy: 0.9646 - val_loss: 0.2202 - val_accuracy: 0.9607
# Epoch 47/50
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.2064 - accuracy: 0.9648 - val_loss: 0.2311 - val_accuracy: 0.9552
# Epoch 48/50
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.2062 - accuracy: 0.9644 - val_loss: 0.2119 - val_accuracy: 0.9622
# Epoch 49/50
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.2056 - accuracy: 0.9652 - val_loss: 0.2215 - val_accuracy: 0.9607
# Epoch 50/50
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.2054 - accuracy: 0.9647 - val_loss: 0.2230 - val_accuracy: 0.9602

# %%
# probability for each class
y_proba = model_images.predict(x_test)
y_proba
# Out:
#  93/313 [=======>......................] - ETA: 0s
# 2023-03-21 12:59:23.510006: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 313/313 [==============================] - 1s 2ms/step
# array([[2.7121656e-05, 1.9177273e-06, 3.1075531e-04, ..., 9.9943268e-01,
#         5.2520659e-07, 1.5094096e-05],
#        [7.8998564e-05, 7.3650572e-04, 9.9668664e-01, ..., 4.3623876e-07,
#         2.4793102e-04, 7.9429324e-11],
#        [1.7819635e-05, 9.9252796e-01, 7.9646794e-04, ..., 3.3436918e-03,
#         1.0683475e-03, 1.1268436e-05],
#        ...,
#        [6.6341497e-09, 7.8726167e-05, 2.4806960e-08, ..., 6.5645768e-04,
#         1.4508008e-06, 1.8977952e-03],
#        [7.9814403e-05, 3.0201996e-05, 1.4780512e-06, ..., 2.7768936e-05,
#         1.6901852e-03, 1.5533160e-05],
#        [6.5364031e-05, 5.3226183e-09, 1.9758834e-05, ..., 2.1522655e-11,
#         1.9076481e-07, 1.0330086e-09]], dtype=float32)

# %%
model_images.evaluate(x_test, y_tt_one_hot, verbose = 2)
# Out:
# 2023-03-21 12:59:24.200628: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 313/313 - 2s - loss: 0.2185 - accuracy: 0.9609 - 2s/epoch - 6ms/step
# [0.21849378943443298, 0.960900068283081]

# %%
train_mnist_history = pd.DataFrame(history_mnist.history)
train_mnist_history.index.name = 'epochs'

col_list = ['loss', 'val_loss']
train_mnist_history[col_list].plot()
plt.ylabel('Categorical cross entropy')
plt.title('Training loss history')
plt.show()

# %%
col_list = ['accuracy', 'val_accuracy']
train_mnist_history[col_list].plot()
plt.ylabel('Accuracy')
plt.title('Training loss history')
plt.show()

# %% [markdown]
# Better validation accuracy:
# - 94.5\% to 96.3\% with regularization
# - no overfitting

# %%
# argmax axis = -1 gets the column index of maximum probability for each row.
# column index corresponds to digit classes (numbers 0 -9)
predicted = np.argmax(y_proba, axis=-1)
predicted
# Out:
# array([7, 2, 1, ..., 4, 5, 6])

# %%
cm_digits = confusion_matrix(y_test, predicted)
disp = ConfusionMatrixDisplay(
    confusion_matrix=cm_digits)

disp.plot(cmap=plt.cm.Blues)
plt.show()

# %% [markdown]
# Regularization:
# - key component to training deeper networks (tend to overfit without regularization)
# - learn higher order features, but don't overtrain on specifics.

# %%
deepermodel_images = Sequential()
deepermodel_images.add(Flatten(input_shape=(28, 28))) # flattens each 28x28 image into a vector
deepermodel_images.add(Dense(32, activation='relu', kernel_regularizer = reg)) # take in regularizer
deepermodel_images.add(Dense(16, activation='relu', kernel_regularizer = reg)) # add another layer
deepermodel_images.add(Dense(16, activation='relu', kernel_regularizer = reg)) # add another layer
deepermodel_images.add(Dense(10, activation='relu', kernel_regularizer = reg))
deepermodel_images.add(Dense(10, activation='softmax')) # number of units = number of target classes

deepermodel_images.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['accuracy'] )

# %%
# will take a while
history_deepermnist = deepermodel_images.fit(x_train, y_tr_one_hot, epochs=100, batch_size= 32, validation_split = 0.2)
# Out:
# Epoch 1/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2422 - accuracy: 0.9656 - val_loss: 0.2588 - val_accuracy: 0.9591
# Epoch 2/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2394 - accuracy: 0.9654 - val_loss: 0.2710 - val_accuracy: 0.9576
# Epoch 3/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2417 - accuracy: 0.9650 - val_loss: 0.2576 - val_accuracy: 0.9597
# Epoch 4/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2431 - accuracy: 0.9650 - val_loss: 0.2515 - val_accuracy: 0.9632
# Epoch 5/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2416 - accuracy: 0.9652 - val_loss: 0.2522 - val_accuracy: 0.9625
# Epoch 6/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2375 - accuracy: 0.9660 - val_loss: 0.2395 - val_accuracy: 0.9662
# Epoch 7/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2403 - accuracy: 0.9656 - val_loss: 0.2506 - val_accuracy: 0.9633
# Epoch 8/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2368 - accuracy: 0.9653 - val_loss: 0.2444 - val_accuracy: 0.9656
# Epoch 9/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2392 - accuracy: 0.9647 - val_loss: 0.2375 - val_accuracy: 0.9647
# Epoch 10/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2381 - accuracy: 0.9657 - val_loss: 0.2533 - val_accuracy: 0.9622
# Epoch 11/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2381 - accuracy: 0.9643 - val_loss: 0.2422 - val_accuracy: 0.9667
# Epoch 12/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2381 - accuracy: 0.9650 - val_loss: 0.2531 - val_accuracy: 0.9613
# Epoch 13/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2374 - accuracy: 0.9654 - val_loss: 0.2384 - val_accuracy: 0.9667
# Epoch 14/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2373 - accuracy: 0.9649 - val_loss: 0.2456 - val_accuracy: 0.9628
# Epoch 15/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2365 - accuracy: 0.9652 - val_loss: 0.2483 - val_accuracy: 0.9626
# Epoch 16/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2348 - accuracy: 0.9666 - val_loss: 0.2371 - val_accuracy: 0.9648
# Epoch 17/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2341 - accuracy: 0.9668 - val_loss: 0.2363 - val_accuracy: 0.9655
# Epoch 18/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2343 - accuracy: 0.9661 - val_loss: 0.2662 - val_accuracy: 0.9538
# Epoch 19/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2352 - accuracy: 0.9652 - val_loss: 0.2385 - val_accuracy: 0.9646
# Epoch 20/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2344 - accuracy: 0.9651 - val_loss: 0.2530 - val_accuracy: 0.9614
# Epoch 21/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2348 - accuracy: 0.9660 - val_loss: 0.2415 - val_accuracy: 0.9642
# Epoch 22/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2332 - accuracy: 0.9654 - val_loss: 0.2365 - val_accuracy: 0.9663
# Epoch 23/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2352 - accuracy: 0.9657 - val_loss: 0.2472 - val_accuracy: 0.9630
# Epoch 24/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2349 - accuracy: 0.9650 - val_loss: 0.2326 - val_accuracy: 0.9663
# Epoch 25/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2329 - accuracy: 0.9659 - val_loss: 0.2414 - val_accuracy: 0.9638
# Epoch 26/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2341 - accuracy: 0.9649 - val_loss: 0.2553 - val_accuracy: 0.9612
# Epoch 27/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2319 - accuracy: 0.9650 - val_loss: 0.2376 - val_accuracy: 0.9653
# Epoch 28/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2300 - accuracy: 0.9660 - val_loss: 0.2474 - val_accuracy: 0.9617
# Epoch 29/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2330 - accuracy: 0.9658 - val_loss: 0.2369 - val_accuracy: 0.9653
# Epoch 30/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2308 - accuracy: 0.9658 - val_loss: 0.2460 - val_accuracy: 0.9629
# Epoch 31/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2325 - accuracy: 0.9652 - val_loss: 0.2471 - val_accuracy: 0.9622
# Epoch 32/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2311 - accuracy: 0.9661 - val_loss: 0.2301 - val_accuracy: 0.9664
# Epoch 33/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2299 - accuracy: 0.9664 - val_loss: 0.2427 - val_accuracy: 0.9621
# Epoch 34/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2310 - accuracy: 0.9647 - val_loss: 0.2398 - val_accuracy: 0.9630
# Epoch 35/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2309 - accuracy: 0.9655 - val_loss: 0.2401 - val_accuracy: 0.9635
# Epoch 36/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2299 - accuracy: 0.9660 - val_loss: 0.2352 - val_accuracy: 0.9635
# Epoch 37/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2308 - accuracy: 0.9653 - val_loss: 0.2420 - val_accuracy: 0.9628
# Epoch 38/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2322 - accuracy: 0.9656 - val_loss: 0.2456 - val_accuracy: 0.9613
# Epoch 39/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2287 - accuracy: 0.9665 - val_loss: 0.2370 - val_accuracy: 0.9636
# Epoch 40/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2303 - accuracy: 0.9647 - val_loss: 0.2430 - val_accuracy: 0.9612
# Epoch 41/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2294 - accuracy: 0.9657 - val_loss: 0.2357 - val_accuracy: 0.9654
# Epoch 42/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2289 - accuracy: 0.9665 - val_loss: 0.2301 - val_accuracy: 0.9667
# Epoch 43/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2315 - accuracy: 0.9648 - val_loss: 0.2392 - val_accuracy: 0.9638
# Epoch 44/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2282 - accuracy: 0.9661 - val_loss: 0.2461 - val_accuracy: 0.9597
# Epoch 45/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2283 - accuracy: 0.9651 - val_loss: 0.2404 - val_accuracy: 0.9632
# Epoch 46/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2305 - accuracy: 0.9651 - val_loss: 0.2410 - val_accuracy: 0.9604
# Epoch 47/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2256 - accuracy: 0.9665 - val_loss: 0.2436 - val_accuracy: 0.9605
# Epoch 48/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2287 - accuracy: 0.9657 - val_loss: 0.2478 - val_accuracy: 0.9626
# Epoch 49/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2276 - accuracy: 0.9655 - val_loss: 0.2355 - val_accuracy: 0.9646
# Epoch 50/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2270 - accuracy: 0.9660 - val_loss: 0.2337 - val_accuracy: 0.9638
# Epoch 51/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2284 - accuracy: 0.9651 - val_loss: 0.2385 - val_accuracy: 0.9628
# Epoch 52/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2272 - accuracy: 0.9657 - val_loss: 0.2399 - val_accuracy: 0.9639
# Epoch 53/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2256 - accuracy: 0.9654 - val_loss: 0.2756 - val_accuracy: 0.9503
# Epoch 54/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2267 - accuracy: 0.9670 - val_loss: 0.2447 - val_accuracy: 0.9630
# Epoch 55/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2286 - accuracy: 0.9653 - val_loss: 0.2483 - val_accuracy: 0.9628
# Epoch 56/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2252 - accuracy: 0.9661 - val_loss: 0.2360 - val_accuracy: 0.9621
# Epoch 57/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2278 - accuracy: 0.9653 - val_loss: 0.2433 - val_accuracy: 0.9619
# Epoch 58/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2235 - accuracy: 0.9670 - val_loss: 0.2432 - val_accuracy: 0.9608
# Epoch 59/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2245 - accuracy: 0.9667 - val_loss: 0.2302 - val_accuracy: 0.9663
# Epoch 60/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2247 - accuracy: 0.9669 - val_loss: 0.2461 - val_accuracy: 0.9617
# Epoch 61/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2283 - accuracy: 0.9648 - val_loss: 0.2499 - val_accuracy: 0.9607
# Epoch 62/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2257 - accuracy: 0.9665 - val_loss: 0.2466 - val_accuracy: 0.9606
# Epoch 63/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2267 - accuracy: 0.9658 - val_loss: 0.2324 - val_accuracy: 0.9653
# Epoch 64/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2252 - accuracy: 0.9669 - val_loss: 0.2560 - val_accuracy: 0.9566
# Epoch 65/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2256 - accuracy: 0.9657 - val_loss: 0.2416 - val_accuracy: 0.9632
# Epoch 66/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2238 - accuracy: 0.9665 - val_loss: 0.2565 - val_accuracy: 0.9592
# Epoch 67/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2251 - accuracy: 0.9665 - val_loss: 0.2352 - val_accuracy: 0.9614
# Epoch 68/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2236 - accuracy: 0.9668 - val_loss: 0.2387 - val_accuracy: 0.9636
# Epoch 69/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2237 - accuracy: 0.9660 - val_loss: 0.2432 - val_accuracy: 0.9602
# Epoch 70/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2237 - accuracy: 0.9662 - val_loss: 0.2425 - val_accuracy: 0.9609
# Epoch 71/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2239 - accuracy: 0.9650 - val_loss: 0.2423 - val_accuracy: 0.9607
# Epoch 72/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2253 - accuracy: 0.9661 - val_loss: 0.2482 - val_accuracy: 0.9585
# Epoch 73/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2233 - accuracy: 0.9668 - val_loss: 0.2448 - val_accuracy: 0.9610
# Epoch 74/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2250 - accuracy: 0.9647 - val_loss: 0.2398 - val_accuracy: 0.9632
# Epoch 75/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2228 - accuracy: 0.9661 - val_loss: 0.2372 - val_accuracy: 0.9644
# Epoch 76/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2266 - accuracy: 0.9654 - val_loss: 0.2409 - val_accuracy: 0.9616
# Epoch 77/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2246 - accuracy: 0.9665 - val_loss: 0.2372 - val_accuracy: 0.9626
# Epoch 78/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2237 - accuracy: 0.9659 - val_loss: 0.2853 - val_accuracy: 0.9485
# Epoch 79/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2234 - accuracy: 0.9656 - val_loss: 0.2315 - val_accuracy: 0.9638
# Epoch 80/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2241 - accuracy: 0.9657 - val_loss: 0.2320 - val_accuracy: 0.9660
# Epoch 81/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2251 - accuracy: 0.9656 - val_loss: 0.2385 - val_accuracy: 0.9608
# Epoch 82/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2242 - accuracy: 0.9656 - val_loss: 0.2513 - val_accuracy: 0.9588
# Epoch 83/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2238 - accuracy: 0.9662 - val_loss: 0.2281 - val_accuracy: 0.9642
# Epoch 84/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2223 - accuracy: 0.9664 - val_loss: 0.2389 - val_accuracy: 0.9605
# Epoch 85/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2245 - accuracy: 0.9651 - val_loss: 0.2284 - val_accuracy: 0.9651
# Epoch 86/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2228 - accuracy: 0.9662 - val_loss: 0.2263 - val_accuracy: 0.9661
# Epoch 87/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2227 - accuracy: 0.9657 - val_loss: 0.2272 - val_accuracy: 0.9657
# Epoch 88/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2241 - accuracy: 0.9654 - val_loss: 0.2365 - val_accuracy: 0.9648
# Epoch 89/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2218 - accuracy: 0.9655 - val_loss: 0.2310 - val_accuracy: 0.9649
# Epoch 90/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2228 - accuracy: 0.9661 - val_loss: 0.2277 - val_accuracy: 0.9654
# Epoch 91/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2182 - accuracy: 0.9667 - val_loss: 0.2601 - val_accuracy: 0.9527
# Epoch 92/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2192 - accuracy: 0.9661 - val_loss: 0.2317 - val_accuracy: 0.9638
# Epoch 93/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2237 - accuracy: 0.9658 - val_loss: 0.2409 - val_accuracy: 0.9607
# Epoch 94/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2218 - accuracy: 0.9655 - val_loss: 0.2317 - val_accuracy: 0.9646
# Epoch 95/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2225 - accuracy: 0.9658 - val_loss: 0.2397 - val_accuracy: 0.9617
# Epoch 96/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2245 - accuracy: 0.9655 - val_loss: 0.2693 - val_accuracy: 0.9537
# Epoch 97/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2210 - accuracy: 0.9665 - val_loss: 0.2293 - val_accuracy: 0.9642
# Epoch 98/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2216 - accuracy: 0.9668 - val_loss: 0.2422 - val_accuracy: 0.9577
# Epoch 99/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2226 - accuracy: 0.9659 - val_loss: 0.2352 - val_accuracy: 0.9619
# Epoch 100/100
# 1500/1500 [==============================] - 15s 10ms/step - loss: 0.2217 - accuracy: 0.9665 - val_loss: 0.2362 - val_accuracy: 0.9642

# %%
#evaluate test accuracy
deepermodel_images.evaluate(x_test, y_tt_one_hot, verbose = 2)
# Out:
# 313/313 - 2s - loss: 0.2297 - accuracy: 0.9641 - 2s/epoch - 7ms/step
# [0.2296561449766159, 0.9641000628471375]

# %%
train_deepmnist_history = pd.DataFrame(history_deepermnist.history)
train_deepmnist_history.index.name = 'epochs'

col_list = ['loss', 'val_loss']
train_deepmnist_history[col_list].plot()
plt.ylabel('Categorical cross entropy')
plt.title('Training loss history')
plt.show()

# %%
col_list = ['accuracy', 'val_accuracy']
train_deepmnist_history[col_list].plot()
plt.ylabel('Accuracy')
plt.title('Training loss history')
plt.show()

# %% [markdown]
# Not overfitting even while adding much more complexity:
# - in this case, not gaining much either

# %% [markdown]
# To do better:
# - try a different regularization technique
# - may need to think harder about network architecture

# %% [markdown]
# #### Dropout Regularization
# - Architecture based strategy.
#
# On each forward/backprop iteration:
# - given layer with dropout
# - shut off activations to randomly selected nodes in layer

# %% [markdown]
# ![drop_out](images/drop_out.png)

# %% [markdown]
# <img src = "Images/dropout_network.gif" >

# %% [markdown]
# - Set $p^{[l]}$  uniform probability of node dropout for given layer
# - each train cycle: kills different activations

# %% [markdown]
# Dead nodes dont contribute to weight updates in backprop.

# %% [markdown]
# after many train cycles: have learned weights:
# - contributions from many different networks learning different things

# %% [markdown]
# <img src = "Images/Deeper_network.jpg">

# %% [markdown]
# Validation/test phase:
# - use all nodes and learned weights.
# - make prediction.

# %% [markdown]
# **Why it works as regularization**
# - network learns not to trust in any one subset of weights: unlikely any particular weight subset gets too big.
# - distributes weights in way that is robust to network noise (random dropout): generalizes well.

# %% [markdown]
# #### Dropout in Keras
#
# - Simply add it as though it were a layer. It will apply to the immediately preceding layer.

# %%
from tensorflow.keras.layers import Dropout

# %% [markdown]
# Dropout() takes in the dropout probability as a constructor argument:
# - Dropout($p$) after some of the hidden layers.
# - $p \in [0.2, 0.5]$ as good range to try.

# %%
from tensorflow.keras.optimizers import Adam
opt = Adam(learning_rate=0.003, beta_1=0.9, beta_2=0.999, epsilon=1e-07)

# %% [markdown]
# **Define model**

# %%
model = Sequential()
model.add(Flatten(input_shape=(28, 28)))
model.add(Dense(20, activation='relu'))
model.add(Dropout(0.2)) # dropout on previous activations
model.add(Dense(12, activation='relu'))
model.add(Dense(12, activation='relu'))
model.add(Dropout(0.1)) # dropout
model.add(Dense(12, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(10, activation ='softmax'))

# compile model
model.compile(optimizer=opt, 
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# Some tips:
# - Dropout earlier in network or inputs. Don't put on final layers.
# - Try faster learning rates in optimizer

# %%
# will take a while
history_dropoutmnist = model.fit(x_train, y_tr_one_hot, epochs=100, batch_size= 32, validation_split = 0.2, verbose =2)
# Out:
# Epoch 1/100
# 2023-03-21 13:56:28.933022: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-03-21 13:56:41.143368: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1500/1500 - 15s - loss: 0.7730 - accuracy: 0.7527 - val_loss: 0.3549 - val_accuracy: 0.9057 - 15s/epoch - 10ms/step
# Epoch 2/100
# 1500/1500 - 15s - loss: 0.4914 - accuracy: 0.8623 - val_loss: 0.3015 - val_accuracy: 0.9178 - 15s/epoch - 10ms/step
# Epoch 3/100
# 1500/1500 - 16s - loss: 0.4423 - accuracy: 0.8756 - val_loss: 0.3220 - val_accuracy: 0.9126 - 16s/epoch - 11ms/step
# Epoch 4/100
# 1500/1500 - 14s - loss: 0.4165 - accuracy: 0.8824 - val_loss: 0.2932 - val_accuracy: 0.9212 - 14s/epoch - 10ms/step
# Epoch 5/100
# 1500/1500 - 14s - loss: 0.3967 - accuracy: 0.8884 - val_loss: 0.2728 - val_accuracy: 0.9289 - 14s/epoch - 9ms/step
# Epoch 6/100
# 1500/1500 - 14s - loss: 0.3787 - accuracy: 0.8932 - val_loss: 0.2525 - val_accuracy: 0.9313 - 14s/epoch - 9ms/step
# Epoch 7/100
# 1500/1500 - 14s - loss: 0.3689 - accuracy: 0.8952 - val_loss: 0.2697 - val_accuracy: 0.9276 - 14s/epoch - 9ms/step
# Epoch 8/100
# 1500/1500 - 14s - loss: 0.3527 - accuracy: 0.9007 - val_loss: 0.2552 - val_accuracy: 0.9321 - 14s/epoch - 9ms/step
# Epoch 9/100
# 1500/1500 - 14s - loss: 0.3475 - accuracy: 0.9018 - val_loss: 0.2508 - val_accuracy: 0.9322 - 14s/epoch - 9ms/step
# Epoch 10/100
# 1500/1500 - 14s - loss: 0.3394 - accuracy: 0.9044 - val_loss: 0.2454 - val_accuracy: 0.9349 - 14s/epoch - 9ms/step
# Epoch 11/100
# 1500/1500 - 14s - loss: 0.3329 - accuracy: 0.9048 - val_loss: 0.2607 - val_accuracy: 0.9322 - 14s/epoch - 9ms/step
# Epoch 12/100
# 1500/1500 - 14s - loss: 0.3276 - accuracy: 0.9064 - val_loss: 0.2385 - val_accuracy: 0.9377 - 14s/epoch - 10ms/step
# Epoch 13/100
# 1500/1500 - 14s - loss: 0.3205 - accuracy: 0.9092 - val_loss: 0.2345 - val_accuracy: 0.9387 - 14s/epoch - 9ms/step
# Epoch 14/100
# 1500/1500 - 14s - loss: 0.3177 - accuracy: 0.9091 - val_loss: 0.2453 - val_accuracy: 0.9367 - 14s/epoch - 9ms/step
# Epoch 15/100
# 1500/1500 - 14s - loss: 0.3145 - accuracy: 0.9112 - val_loss: 0.2308 - val_accuracy: 0.9352 - 14s/epoch - 9ms/step
# Epoch 16/100
# 1500/1500 - 14s - loss: 0.3039 - accuracy: 0.9133 - val_loss: 0.2369 - val_accuracy: 0.9360 - 14s/epoch - 9ms/step
# Epoch 17/100
# 1500/1500 - 14s - loss: 0.2980 - accuracy: 0.9144 - val_loss: 0.2424 - val_accuracy: 0.9362 - 14s/epoch - 9ms/step
# Epoch 18/100
# 1500/1500 - 14s - loss: 0.3017 - accuracy: 0.9131 - val_loss: 0.2541 - val_accuracy: 0.9317 - 14s/epoch - 9ms/step
# Epoch 19/100
# 1500/1500 - 14s - loss: 0.2981 - accuracy: 0.9151 - val_loss: 0.2335 - val_accuracy: 0.9404 - 14s/epoch - 9ms/step
# Epoch 20/100
# 1500/1500 - 14s - loss: 0.2915 - accuracy: 0.9168 - val_loss: 0.2320 - val_accuracy: 0.9370 - 14s/epoch - 9ms/step
# Epoch 21/100
# 1500/1500 - 14s - loss: 0.2944 - accuracy: 0.9158 - val_loss: 0.2303 - val_accuracy: 0.9379 - 14s/epoch - 9ms/step
# Epoch 22/100
# 1500/1500 - 15s - loss: 0.2863 - accuracy: 0.9195 - val_loss: 0.2337 - val_accuracy: 0.9347 - 15s/epoch - 10ms/step
# Epoch 23/100
# 1500/1500 - 14s - loss: 0.2853 - accuracy: 0.9181 - val_loss: 0.2381 - val_accuracy: 0.9373 - 14s/epoch - 10ms/step
# Epoch 24/100
# 1500/1500 - 14s - loss: 0.2792 - accuracy: 0.9216 - val_loss: 0.2266 - val_accuracy: 0.9407 - 14s/epoch - 10ms/step
# Epoch 25/100
# 1500/1500 - 14s - loss: 0.2781 - accuracy: 0.9211 - val_loss: 0.2396 - val_accuracy: 0.9363 - 14s/epoch - 9ms/step
# Epoch 26/100
# 1500/1500 - 14s - loss: 0.2801 - accuracy: 0.9195 - val_loss: 0.2152 - val_accuracy: 0.9437 - 14s/epoch - 9ms/step
# Epoch 27/100
# 1500/1500 - 14s - loss: 0.2737 - accuracy: 0.9219 - val_loss: 0.2182 - val_accuracy: 0.9408 - 14s/epoch - 9ms/step
# Epoch 28/100
# 1500/1500 - 14s - loss: 0.2721 - accuracy: 0.9222 - val_loss: 0.2186 - val_accuracy: 0.9412 - 14s/epoch - 9ms/step
# Epoch 29/100
# 1500/1500 - 14s - loss: 0.2704 - accuracy: 0.9228 - val_loss: 0.2185 - val_accuracy: 0.9388 - 14s/epoch - 9ms/step
# Epoch 30/100
# 1500/1500 - 14s - loss: 0.2713 - accuracy: 0.9239 - val_loss: 0.2127 - val_accuracy: 0.9437 - 14s/epoch - 9ms/step
# Epoch 31/100
# 1500/1500 - 14s - loss: 0.2686 - accuracy: 0.9246 - val_loss: 0.2183 - val_accuracy: 0.9428 - 14s/epoch - 9ms/step
# Epoch 32/100
# 1500/1500 - 14s - loss: 0.2660 - accuracy: 0.9241 - val_loss: 0.2158 - val_accuracy: 0.9427 - 14s/epoch - 9ms/step
# Epoch 33/100
# 1500/1500 - 14s - loss: 0.2656 - accuracy: 0.9251 - val_loss: 0.2223 - val_accuracy: 0.9404 - 14s/epoch - 9ms/step
# Epoch 34/100
# 1500/1500 - 14s - loss: 0.2667 - accuracy: 0.9246 - val_loss: 0.2250 - val_accuracy: 0.9375 - 14s/epoch - 10ms/step
# Epoch 35/100
# 1500/1500 - 14s - loss: 0.2638 - accuracy: 0.9246 - val_loss: 0.2166 - val_accuracy: 0.9402 - 14s/epoch - 9ms/step
# Epoch 36/100
# 1500/1500 - 14s - loss: 0.2605 - accuracy: 0.9259 - val_loss: 0.2142 - val_accuracy: 0.9437 - 14s/epoch - 10ms/step
# Epoch 37/100
# 1500/1500 - 14s - loss: 0.2658 - accuracy: 0.9254 - val_loss: 0.2145 - val_accuracy: 0.9418 - 14s/epoch - 9ms/step
# Epoch 38/100
# 1500/1500 - 14s - loss: 0.2617 - accuracy: 0.9259 - val_loss: 0.2257 - val_accuracy: 0.9402 - 14s/epoch - 9ms/step
# Epoch 39/100
# 1500/1500 - 14s - loss: 0.2598 - accuracy: 0.9266 - val_loss: 0.2319 - val_accuracy: 0.9408 - 14s/epoch - 9ms/step
# Epoch 40/100
# 1500/1500 - 14s - loss: 0.2576 - accuracy: 0.9275 - val_loss: 0.2259 - val_accuracy: 0.9405 - 14s/epoch - 9ms/step
# Epoch 41/100
# 1500/1500 - 14s - loss: 0.2561 - accuracy: 0.9277 - val_loss: 0.2269 - val_accuracy: 0.9403 - 14s/epoch - 9ms/step
# Epoch 42/100
# 1500/1500 - 14s - loss: 0.2565 - accuracy: 0.9270 - val_loss: 0.2228 - val_accuracy: 0.9404 - 14s/epoch - 9ms/step
# Epoch 43/100
# 1500/1500 - 14s - loss: 0.2545 - accuracy: 0.9290 - val_loss: 0.2198 - val_accuracy: 0.9395 - 14s/epoch - 9ms/step
# Epoch 44/100
# 1500/1500 - 14s - loss: 0.2585 - accuracy: 0.9270 - val_loss: 0.2264 - val_accuracy: 0.9403 - 14s/epoch - 9ms/step
# Epoch 45/100
# 1500/1500 - 14s - loss: 0.2528 - accuracy: 0.9288 - val_loss: 0.2282 - val_accuracy: 0.9394 - 14s/epoch - 10ms/step
# Epoch 46/100
# 1500/1500 - 14s - loss: 0.2528 - accuracy: 0.9287 - val_loss: 0.2318 - val_accuracy: 0.9368 - 14s/epoch - 9ms/step
# Epoch 47/100
# 1500/1500 - 14s - loss: 0.2541 - accuracy: 0.9277 - val_loss: 0.2130 - val_accuracy: 0.9431 - 14s/epoch - 9ms/step
# Epoch 48/100
# 1500/1500 - 14s - loss: 0.2511 - accuracy: 0.9285 - val_loss: 0.2210 - val_accuracy: 0.9422 - 14s/epoch - 9ms/step
# Epoch 49/100
# 1500/1500 - 14s - loss: 0.2500 - accuracy: 0.9300 - val_loss: 0.2212 - val_accuracy: 0.9408 - 14s/epoch - 9ms/step
# Epoch 50/100
# 1500/1500 - 14s - loss: 0.2474 - accuracy: 0.9296 - val_loss: 0.2141 - val_accuracy: 0.9423 - 14s/epoch - 9ms/step
# Epoch 51/100
# 1500/1500 - 14s - loss: 0.2488 - accuracy: 0.9283 - val_loss: 0.2126 - val_accuracy: 0.9429 - 14s/epoch - 9ms/step
# Epoch 52/100
# 1500/1500 - 14s - loss: 0.2486 - accuracy: 0.9305 - val_loss: 0.2285 - val_accuracy: 0.9412 - 14s/epoch - 9ms/step
# Epoch 53/100
# 1500/1500 - 14s - loss: 0.2460 - accuracy: 0.9305 - val_loss: 0.2218 - val_accuracy: 0.9390 - 14s/epoch - 9ms/step
# Epoch 54/100
# 1500/1500 - 14s - loss: 0.2512 - accuracy: 0.9305 - val_loss: 0.2066 - val_accuracy: 0.9422 - 14s/epoch - 9ms/step
# Epoch 55/100
# 1500/1500 - 14s - loss: 0.2446 - accuracy: 0.9309 - val_loss: 0.2193 - val_accuracy: 0.9383 - 14s/epoch - 9ms/step
# Epoch 56/100
# 1500/1500 - 14s - loss: 0.2448 - accuracy: 0.9303 - val_loss: 0.2061 - val_accuracy: 0.9432 - 14s/epoch - 9ms/step
# Epoch 57/100
# 1500/1500 - 14s - loss: 0.2449 - accuracy: 0.9302 - val_loss: 0.2287 - val_accuracy: 0.9365 - 14s/epoch - 9ms/step
# Epoch 58/100
# 1500/1500 - 14s - loss: 0.2439 - accuracy: 0.9314 - val_loss: 0.2180 - val_accuracy: 0.9439 - 14s/epoch - 9ms/step
# Epoch 59/100
# 1500/1500 - 15s - loss: 0.2442 - accuracy: 0.9311 - val_loss: 0.2196 - val_accuracy: 0.9427 - 15s/epoch - 10ms/step
# Epoch 60/100
# 1500/1500 - 14s - loss: 0.2445 - accuracy: 0.9312 - val_loss: 0.2194 - val_accuracy: 0.9417 - 14s/epoch - 10ms/step
# Epoch 61/100
# 1500/1500 - 15s - loss: 0.2424 - accuracy: 0.9320 - val_loss: 0.2293 - val_accuracy: 0.9402 - 15s/epoch - 10ms/step
# Epoch 62/100
# 1500/1500 - 14s - loss: 0.2429 - accuracy: 0.9309 - val_loss: 0.2225 - val_accuracy: 0.9416 - 14s/epoch - 10ms/step
# Epoch 63/100
# 1500/1500 - 14s - loss: 0.2436 - accuracy: 0.9313 - val_loss: 0.2119 - val_accuracy: 0.9457 - 14s/epoch - 9ms/step
# Epoch 64/100
# 1500/1500 - 14s - loss: 0.2453 - accuracy: 0.9301 - val_loss: 0.2136 - val_accuracy: 0.9440 - 14s/epoch - 9ms/step
# Epoch 65/100
# 1500/1500 - 14s - loss: 0.2389 - accuracy: 0.9317 - val_loss: 0.2221 - val_accuracy: 0.9420 - 14s/epoch - 9ms/step
# Epoch 66/100
# 1500/1500 - 14s - loss: 0.2403 - accuracy: 0.9315 - val_loss: 0.2266 - val_accuracy: 0.9403 - 14s/epoch - 9ms/step
# Epoch 67/100
# 1500/1500 - 14s - loss: 0.2355 - accuracy: 0.9325 - val_loss: 0.2123 - val_accuracy: 0.9430 - 14s/epoch - 9ms/step
# Epoch 68/100
# 1500/1500 - 14s - loss: 0.2373 - accuracy: 0.9332 - val_loss: 0.2136 - val_accuracy: 0.9425 - 14s/epoch - 9ms/step
# Epoch 69/100
# 1500/1500 - 14s - loss: 0.2401 - accuracy: 0.9328 - val_loss: 0.2126 - val_accuracy: 0.9442 - 14s/epoch - 9ms/step
# Epoch 70/100
# 1500/1500 - 14s - loss: 0.2385 - accuracy: 0.9346 - val_loss: 0.2072 - val_accuracy: 0.9465 - 14s/epoch - 9ms/step
# Epoch 71/100
# 1500/1500 - 14s - loss: 0.2380 - accuracy: 0.9343 - val_loss: 0.2210 - val_accuracy: 0.9413 - 14s/epoch - 9ms/step
# Epoch 72/100
# 1500/1500 - 14s - loss: 0.2406 - accuracy: 0.9330 - val_loss: 0.2146 - val_accuracy: 0.9420 - 14s/epoch - 9ms/step
# Epoch 73/100
# 1500/1500 - 14s - loss: 0.2359 - accuracy: 0.9332 - val_loss: 0.2218 - val_accuracy: 0.9414 - 14s/epoch - 10ms/step
# Epoch 74/100
# 1500/1500 - 15s - loss: 0.2381 - accuracy: 0.9332 - val_loss: 0.2137 - val_accuracy: 0.9414 - 15s/epoch - 10ms/step
# Epoch 75/100
# 1500/1500 - 15s - loss: 0.2377 - accuracy: 0.9329 - val_loss: 0.2148 - val_accuracy: 0.9450 - 15s/epoch - 10ms/step
# Epoch 76/100
# 1500/1500 - 14s - loss: 0.2353 - accuracy: 0.9338 - val_loss: 0.2123 - val_accuracy: 0.9440 - 14s/epoch - 9ms/step
# Epoch 77/100
# 1500/1500 - 14s - loss: 0.2367 - accuracy: 0.9333 - val_loss: 0.2189 - val_accuracy: 0.9423 - 14s/epoch - 10ms/step
# Epoch 78/100
# 1500/1500 - 14s - loss: 0.2353 - accuracy: 0.9340 - val_loss: 0.2231 - val_accuracy: 0.9402 - 14s/epoch - 9ms/step
# Epoch 79/100
# 1500/1500 - 14s - loss: 0.2351 - accuracy: 0.9343 - val_loss: 0.2198 - val_accuracy: 0.9423 - 14s/epoch - 9ms/step
# Epoch 80/100
# 1500/1500 - 14s - loss: 0.2342 - accuracy: 0.9338 - val_loss: 0.2181 - val_accuracy: 0.9437 - 14s/epoch - 9ms/step
# Epoch 81/100
# 1500/1500 - 14s - loss: 0.2360 - accuracy: 0.9343 - val_loss: 0.2289 - val_accuracy: 0.9392 - 14s/epoch - 9ms/step
# Epoch 82/100
# 1500/1500 - 14s - loss: 0.2332 - accuracy: 0.9352 - val_loss: 0.2197 - val_accuracy: 0.9411 - 14s/epoch - 9ms/step
# Epoch 83/100
# 1500/1500 - 14s - loss: 0.2313 - accuracy: 0.9352 - val_loss: 0.2246 - val_accuracy: 0.9398 - 14s/epoch - 9ms/step
# Epoch 84/100
# 1500/1500 - 14s - loss: 0.2369 - accuracy: 0.9338 - val_loss: 0.2321 - val_accuracy: 0.9369 - 14s/epoch - 9ms/step
# Epoch 85/100
# 1500/1500 - 14s - loss: 0.2320 - accuracy: 0.9337 - val_loss: 0.2170 - val_accuracy: 0.9423 - 14s/epoch - 9ms/step
# Epoch 86/100
# 1500/1500 - 14s - loss: 0.2318 - accuracy: 0.9345 - val_loss: 0.2249 - val_accuracy: 0.9399 - 14s/epoch - 9ms/step
# Epoch 87/100
# 1500/1500 - 14s - loss: 0.2337 - accuracy: 0.9351 - val_loss: 0.2148 - val_accuracy: 0.9423 - 14s/epoch - 9ms/step
# Epoch 88/100
# 1500/1500 - 14s - loss: 0.2324 - accuracy: 0.9355 - val_loss: 0.2135 - val_accuracy: 0.9429 - 14s/epoch - 9ms/step
# Epoch 89/100
# 1500/1500 - 14s - loss: 0.2320 - accuracy: 0.9345 - val_loss: 0.2261 - val_accuracy: 0.9403 - 14s/epoch - 9ms/step
# Epoch 90/100
# 1500/1500 - 14s - loss: 0.2305 - accuracy: 0.9349 - val_loss: 0.2234 - val_accuracy: 0.9377 - 14s/epoch - 9ms/step
# Epoch 91/100
# 1500/1500 - 14s - loss: 0.2292 - accuracy: 0.9354 - val_loss: 0.2108 - val_accuracy: 0.9431 - 14s/epoch - 9ms/step
# Epoch 92/100
# 1500/1500 - 14s - loss: 0.2311 - accuracy: 0.9358 - val_loss: 0.2248 - val_accuracy: 0.9421 - 14s/epoch - 9ms/step
# Epoch 93/100
# 1500/1500 - 14s - loss: 0.2342 - accuracy: 0.9344 - val_loss: 0.2259 - val_accuracy: 0.9423 - 14s/epoch - 9ms/step
# Epoch 94/100
# 1500/1500 - 14s - loss: 0.2244 - accuracy: 0.9371 - val_loss: 0.2162 - val_accuracy: 0.9413 - 14s/epoch - 9ms/step
# Epoch 95/100
# 1500/1500 - 14s - loss: 0.2318 - accuracy: 0.9350 - val_loss: 0.2165 - val_accuracy: 0.9435 - 14s/epoch - 9ms/step
# Epoch 96/100
# 1500/1500 - 14s - loss: 0.2243 - accuracy: 0.9382 - val_loss: 0.2287 - val_accuracy: 0.9370 - 14s/epoch - 9ms/step
# Epoch 97/100
# 1500/1500 - 14s - loss: 0.2271 - accuracy: 0.9370 - val_loss: 0.2168 - val_accuracy: 0.9445 - 14s/epoch - 9ms/step
# Epoch 98/100
# 1500/1500 - 14s - loss: 0.2271 - accuracy: 0.9359 - val_loss: 0.2129 - val_accuracy: 0.9427 - 14s/epoch - 9ms/step
# Epoch 99/100
# 1500/1500 - 14s - loss: 0.2273 - accuracy: 0.9370 - val_loss: 0.2157 - val_accuracy: 0.9412 - 14s/epoch - 9ms/step
# Epoch 100/100
# 1500/1500 - 14s - loss: 0.2287 - accuracy: 0.9355 - val_loss: 0.2213 - val_accuracy: 0.9421 - 14s/epoch - 9ms/step

# %% [markdown]
# Accuracy on train set will be lower in any given cycle:
# - some activation killed randomly on training.
#
# Performance on validation will be high:
# - uses full network with learned weights for validation

# %% [markdown]
# Not overtraining despite high model capacity:
# - many hidden layers

# %%
train_dropoutmnist_history = pd.DataFrame(history_dropoutmnist.history)
train_dropoutmnist_history.index.name = 'epochs'

col_list = ['loss', 'val_loss']
train_dropoutmnist_history[col_list].plot()
plt.ylabel('Categorical cross entropy')
plt.title('Training loss history')
plt.show()

# %%
col_list = ['accuracy', 'val_accuracy']
train_dropoutmnist_history[col_list].plot()
plt.ylabel('Accuracy')
plt.title('Training loss history')
plt.show()

# %% [markdown]
# Evaluate on test set.

# %%
model.evaluate(x_test, y_tt_one_hot, verbose =0)
# Out:
# 2023-03-21 14:25:05.539313: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# [0.2248380184173584, 0.9389000535011292]

# %% [markdown]
# #### Dropout regularization in conjunction with L2:
#
# - can be used to train very deep networks
# - model complex relationships without overfitting
# - works best in these cases with a lot of data

# %% [markdown]
# Next up:
# - doing much better with a more suitable network architecture
# - Convolutional Neural Networks (CNNs)
